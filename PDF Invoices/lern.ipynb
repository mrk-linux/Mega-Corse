# %% [markdown]
# Day 1
#
# I created `main.py`, a directory named "Invoices", and a `README.md` file.
#
# ---

# %% [markdown]
# Day 2
#
# load the Excel files into data frames
#
# **Run this command in the terminal:** `pip install openpyxl`

# %%
import pandas as pd 
import glob


filepaths = glob.glob("Invoices/*.xlsx")
#Return a list of paths matching a pathname pattern.

for filepath in filepaths:
    df = pd.read_excel(filepath) #Read an Excel file into a DataFrame.
    print(df)
